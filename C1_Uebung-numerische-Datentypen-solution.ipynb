# %% [markdown]
# # Übungen zu den numerischen Datentypen

# %% [markdown]
# ## Aufgabe 1:
#
# Erstellen Sie zwei Variablen. Nutzen Sie sprechende Variablennamen.
#
# Die erste Variable hat Ihren Vornamen als Wert vom Datentyp String. Die zweite Variable hat Ihren Nachnamen als Wert, der vom Datentyp String ist.
#
# Geben Sie Vornamen und Nachnamem mit dem `print()`-Befehl aus.
#
# Checken Sie den Datentyp mit `type()`.

# %%
first_name = 'Martin'
last_name = 'Dröge'

print(first_name, last_name)
# Out:
# Martin Dröge

# %%
print('Datentyp der Variable first_name:', first_name, type(first_name))
print('Datentyp der Variable last_name:', last_name, type(last_name))
# Out:
# Datentyp der Variable first_name: Martin <class 'str'>
# Datentyp der Variable last_name: Dröge <class 'str'>

# %% [markdown]
# ## Aufgabe 2:
#
# Erstellen Sie drei Variablen und weisen diesen Integer-Werte zu. Nutzen Sie die Variablen, um verschiedene arithmetische Operationen durchzuführen:
# * Addition
# * Substraktion
# * Multiplikation
# * Division
# * Exponenten
# * Modulus-Operator
# * Floor-Division
#
# Beschreiben Sie mit Kommentaren in den Zellen, was bei den arithmetischen Operationen geschieht.
#
# Checken Sie auch hier die Datentypen der zurückgegebenen Werte.

# %%
# assign variables

x = 6
y = 7
z = 23

# %%
# add
x + y
# Out:
# 13

# %%
# substract
z - y - x
# Out:
# 10

# %%
# multiply

x * y
# Out:
# 42

# %%
# divide

z / x
# Out:
# 3.8333333333333335

# %%
# floor-Division

z // x
# Out:
# 3

# %%
# modulus
z % x
# Out:
# 5

# %% [markdown]
# ## Aufgabe 3:
#
# Erstellen Sie je eine Variable der Datentypen `int`, `float`, `str`.
#
# Wandeln Sie:
# * `int` in  `float` um
# * `float` in  `str` um
# * `str` in `int` um
#
# Führen Sie arithmetische Operationen durch die
# * ohne Fehlermeldung durchlaufen
# * die eine Fehlermeldung werfen
#
# Checken Sie auch hier die Datentypen der zurückgegebenen Werte.

# %%
# assign variables

var_int = 5
var_float = 7.5
var_str = '35'

# %%
float(var_int)
# Out:
# 5.0

# %%
str(var_float)
# Out:
# '7.5'

# %%
print(int(var_str))
type(int(var_str))
# Out:
# 35
# int

# %%
var_int * var_float
# Out:
# 37.5

# %%
var_int * var_str
# Out:
# '3535353535'

# %%
var_str / var_float
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15268/3521620353.py in <module>
# ----> 1 var_str / var_float
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'
